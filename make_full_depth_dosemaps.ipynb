# %%
# I need to generate all full-depth dosemaps for the whole GALEX corpus to use for stacking to create the 
# hotspot mask movie 


# 1) check which eclipses have extended photonlists (parquet files) in backplanetest and compare to list of all GR7
# eclipses 

# 2) use existing 1 s depth dose maps to make stacks and see if you can see anything 

# 3) generate full-depth dose maps with make_backplanes for all eclispes 

# 4)

# %%
import matplotlib.pyplot as plt 
import pandas as pd
from pyarrow import parquet 
import numpy as np

# %%
park = parquet.read_table('/home/bekah/Downloads/e00754-fd-b00.parquet').to_pandas()

# %%
park
# Out:
#                     t  xb  xamc  yb  yamc   q  xa  ya             x  \
# 0        7.400271e+08   4   338   4   691   8   1   3   8760.280273
# 1        7.400271e+08   4  1768   3 -1731   8  21   8  19885.679688
# 2        7.400271e+08   6   136   5    34   7  18   1  38262.042969
# 3        7.400271e+08   4  1479   3 -1266  16  22  15  17637.259766
# 4        7.400271e+08   4   316   4  -232   7  15  10   8589.120117
# ...               ...  ..   ...  ..   ...  ..  ..  ..           ...
# 1187589  7.400288e+08   2  -783   3  1149  11  29  28 -31034.419922
# 1187590  7.400288e+08   2 -1550   1  1218  15  30   4 -37001.679688
# 1187591  7.400288e+08   3  -835   2   830  14  28  25 -15902.320312
# 1187592  7.400288e+08   3   314   4     2  12  16  29  -6963.100098
# 1187593  7.400288e+08   3  -371   3  -833  21  29  25 -12292.400391
#
#                     y  ...         col         row  flags  ra  dec  \
# 0        21384.888672  ...  305.409241  144.072922      7 NaN  NaN
# ...

# %%
plt.hist(park['flags'])
# Out:
# (array([534696.,      0.,      0.,      0.,      0.,   2279.,      0.,
#              0.,      0., 650619.]),
#  array([ 0. ,  1.2,  2.4,  3.6,  4.8,  6. ,  7.2,  8.4,  9.6, 10.8, 12. ]),
#  <BarContainer object of 10 artists>)
