# %%
import sys
import pandas as pd 
sys.path.insert(0, '/home/bekah/gPhoton2')
from gPhoton.pipeline import execute_pipeline
from astropy.io import fits
from io import BytesIO
import numpy as np 
import os
import matplotlib.pyplot as plt
from gPhoton.coadd import zero_flag_and_edge
import pyarrow.parquet as parquet
from quickbin import bin2d

from photutils.background import Background2D, MedianBackground
from astropy.stats import SigmaClip

# %%
# make a list of fuv to make / look at 

og_aspect = parquet.read_table('/home/bekah/gPhoton2/gPhoton/aspect/metadata.parquet').to_pandas()
og_aspect = og_aspect.dropna(subset=['fuv_temp'])

og_aspect = og_aspect[og_aspect['legs'] == 0]

sampled_eclipses = og_aspect.sample(n=200, random_state=5)
sampled_eclipses
# Out:
#        eclipse  obstype  legs      ra_max      ra_min    dec_max    dec_min  \
# 19826    27659      GII     0  217.875486  217.845199  33.022857  32.999250
# 3278      6545      DIS     0  327.513299  327.486418  -5.429757  -5.459383
# 1452      3949      MIS     0  173.867493  173.804831  65.346462  65.320220
# 18006    25167      NGS     0  145.961966  145.938913  13.382225  13.358151
# 18895    26267      DIS     0  164.251111  164.226567  -3.606646  -3.631821
# ...        ...      ...   ...         ...         ...        ...        ...
# 4110      7572      NGS     0    8.496748    8.462812  40.700387  40.674567
# 1047      3079  unknown     0   48.695838   45.524710  -4.505882 -10.325173
# 11835    17548      GII     0  315.391709  315.366712  16.189142  16.165102
# 17290    23996      MIS     0   15.048236   15.015845  -0.765801  -0.791284
# 19237    26669      MIS     0  226.427551  226.402296   1.328570   1.302433
#
#         fuv_temp
# 19826  26.183196
# 3278   28.592048
# 1452   30.499527
# 18006  26.671233
# 18895  28.932825
# ...          ...
# 4110   29.011488
# 1047   32.422420
# 11835  29.392171
# 17290  29.782006
# 19237  27.021584
#
# [200 rows x 8 columns]

# %%
for index, eclipse in sampled_eclipses['eclipse'].items():
    print(f"running {eclipse}")
    try: 
        execute_pipeline(
                int(eclipse),
                "NUV",
                depth=None,
                # integer; None to deactivate (default None)
                threads=4,
                # where to both write output data and look for input data
                local_root="/media/bekah/BekahA/background_test/pics_and_photonlists",
                # auxiliary remote location for input data
                # remote_root="/mnt/s3",
                recreate=True,
                # list of floats; relevant only to lightcurve / photometry portion
                aperture_sizes=[12.8],
                # actually write image/movie products? otherwise hold in memory but
                # discard (possibly after performing photometry).
                write={"movie": False, "image": True},
                coregister_lightcurves=False,
                # photonpipe, moviemaker, None (default None)
                stop_after=None,
                photometry_only=False,
                # None, "gzip", "rice"
                compression="rice",
                # use array sparsification on movie frames?
                lil=False,
                # write movie frames as separate files
                burst=False,
                extended_photonlist=True,
                # aspect file, don't need to set unless need to use alt
                # file, 'aspect2.parquet'
            )
        
    except Exception as e: 
        print(e)
# Out:
# running 27659
# /home/bekah/gPhoton2/gPhoton/pipeline.py:231: UserWarning: lil=False is deprected and will be removed in a future release. Defaulting to lil=True.
#   warnings.warn("lil=False is deprected and will be removed in a future release. Defaulting to lil=True.")
# starting timer
# eclipse 27659 NUV  -- GII; 0 leg(s)
# downloading raw6file
# Processing eclipse 27659
# trange= ( 899226753.995 , 899227927.995 )
# RA AVG: 217.8627899144684, DEC AVG: 33.01200472154652, ROLL AVG: 330.0008487650002
# Loading raw6 file...
# 18646431 events
# Unpacking raw6 data...
# stim_coef0, stim_coef1 = -209773.9415523312, 0.0002389604966574879
# writing table to /media/bekah/BekahA/background_test/pics_and_photonlists/e27659/e27659-nd-b00.parquet
#
# Runtime statistics:
#  runtime		=	24.26 sec. = (0.4 min.)
#   processed	   =   18501153 of 18646431 events.
# rate		=	768533.61 photons/sec.
#
# masking photonlist
# reading photonlist
# filtering photonlist
# calculating expt & adding edge points
# quickbinning
# masking binned data
# making & saving new masks
# saving new masks.
# 68.28 elapsed seconds, restarting timer
# making images from /media/bekah/BekahA/background_test/pics_and_photonlists/e27659/e27659-nd-b00.parquet
# indexing data and making WCS solution
# making full-depth image
# 7.94 elapsed seconds, restarting timer
# Extracting sources with DAOFIND.
# Masking for extended sources.
# Running DAO for extended source ID.
# Found 1903 peaks with DAO.
# 1903
# Estimating background and threshold.
# Calculating source threshold.
# Segmenting and deblending point sources.
# Checking for extended source overlap with point sources.
# Located 5387 sources.
# 9.34 elapsed seconds, restarting timer
# 0.56 elapsed seconds, restarting timer
# 'expfile'
# running 6545
# starting timer
# eclipse 6545 NUV  -- DIS; 0 leg(s)
# downloading raw6file
# /home/bekah/gPhoton2/gPhoton/pipeline.py:231: UserWarning: lil=False is deprected and will be removed in a future release. Defaulting to lil=True.
#   warnings.warn("lil=False is deprected and will be removed in a future release. Defaulting to lil=True.")
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 4
#       2 print(f"running {eclipse}")
#       3 try:
# ----> 4     execute_pipeline(
#       5             int(eclipse),
#       6             "NUV",
#       7             depth=None,
#       8             # integer; None to deactivate (default None)
#       9             threads=4,
#      10             # where to both write output data and look for input data
#      11             local_root="/media/bekah/BekahA/background_test/pics_and_photonlists",
#      12             # auxiliary remote location for input data
#      13             # remote_root="/mnt/s3",
#      14             recreate=True,
#      15             # list of floats; relevant only to lightcurve / photometry portion
#      16             aperture_sizes=[12.8],
#      17             # actually write image/movie products? otherwise hold in memory but
#      18             # discard (possibly after performing photometry).
#      19             write={"movie": False, "image": True},
#      20             coregister_lightcurves=False,
#      21             # photonpipe, moviemaker, None (default None)
#      22             stop_after=None,
#      23             photometry_only=False,
#      24             # None, "gzip", "rice"
#      25             compression="rice",
#      26             # use array sparsification on movie frames?
#      27             lil=False,
#      28             # write movie frames as separate files
#      29             burst=False,
#      30             extended_photonlist=True,
#      31             # aspect file, don't need to set unless need to use alt
#      32             # file, 'aspect2.parquet'
#      33         )
#      35 except Exception as e:
#      36     print(e)
#
# File ~/gPhoton2/gPhoton/pipeline.py:263, in execute_pipeline(eclipse, band, depth, threads, local_root, remote_root, download, recreate, verbose, source_catalog_file, write, aperture_sizes, lil, coregister_lightcurves, stop_after, compression, hdu_constructor_kwargs, min_exptime, photometry_only, burst, chunksz, share_memory, extended_photonlist, aspect, override_eclipse_limits, extraction_threshold, suffix)
#     261 if photometry_only:
#     262     return execute_photometry_only(ctx)
# --> 263 return execute_full_pipeline(ctx)
#
# File ~/gPhoton2/gPhoton/pipeline.py:286, in execute_full_pipeline(ctx)
#     283     return execute_photometry_only(ctx)
#     285 # fetch, locate, or create photonlist, as requested
# --> 286 get_photonlist_result = get_photonlists(ctx, raise_errors=False)
#     287 # we received an error return code
#     288 if isinstance(get_photonlist_result, str):
#
# File ~/gPhoton2/gPhoton/pipeline.py:51, in get_photonlists(ctx, raise_errors)
#      46         print(
#      47             f"using existing photon list(s): "
#      48             f"{[str(path) for path in photonpaths]}"
#      49         )
#      50         return photonpaths
# ---> 51 raw6path = _look_for_raw6(ctx)
#      52 if not raw6path.exists():
#      53     print("couldn't find raw6 file.")
#
# File ~/gPhoton2/gPhoton/pipeline.py:388, in _look_for_raw6(ctx)
#     385 from gPhoton.io.mast import retrieve_raw6
#     387 print("downloading raw6file")
# --> 388 raw6file = retrieve_raw6(ctx.eclipse, ctx.band, raw6path)
#     389 if raw6file is not None:
#     390     raw6path = Path(raw6file)
#
# File ~/gPhoton2/gPhoton/io/mast.py:128, in retrieve_raw6(eclipse, band, outbase)
#     126 def retrieve_raw6(eclipse: int, band: GalexBand, outbase: Pathlike) -> str:
#     127     """retrieve raw6 (L0 telemetry) file from MAST and save it to outbase."""
# --> 128     raw6file = download_data(
#     129         eclipse, "raw6", band, datadir=os.path.dirname(outbase),
#     130     )
#     131     if raw6file is None:
#     132         raise ValueError("Unable to retrieve raw6 file for this eclipse.")
#
# File ~/gPhoton2/gPhoton/io/mast.py:104, in download_data(eclipse, ftype, band, datadir, verbose)
#     101 else:
#     102     # TODO: investigate handling options for different error cases
#     103     try:
# --> 104         chunked_download(url, opath, render_bar=verbose > 0)
#     105     except Exception as ex:
#     106         print(f"Unable to download data from {url}: {type(ex)}: {ex}")
#
# File ~/gPhoton2/gPhoton/io/netutils.py:23, in chunked_download(url, destination, chunk_size_mb, render_bar)
#      13 def chunked_download(
#      14     url: str,
#      15     destination: str,
#      16     chunk_size_mb: int = 10,
#      17     render_bar: bool = True
#      18 ) -> None:
#      19     """
#      20     download a file from url to destination in chunks of chunk_size_mb MB,
#      21     optionally rendering a progress bar.
#      22     """
# ---> 23     response = requests.get(url, stream=True)
#      24     response.raise_for_status()
#      25     if "Content-Length" in response.headers:
#
# File ~/mambaforge/envs/gphoton2/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/mambaforge/envs/gphoton2/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/mambaforge/envs/gphoton2/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/mambaforge/envs/gphoton2/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/mambaforge/envs/gphoton2/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/mambaforge/envs/gphoton2/lib/python3.11/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~/mambaforge/envs/gphoton2/lib/python3.11/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/mambaforge/envs/gphoton2/lib/python3.11/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File ~/mambaforge/envs/gphoton2/lib/python3.11/http/client.py:1378, in HTTPConnection.getresponse(self)
#    1376 try:
#    1377     try:
# -> 1378         response.begin()
#    1379     except ConnectionError:
#    1380         self.close()
#
# File ~/mambaforge/envs/gphoton2/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~/mambaforge/envs/gphoton2/lib/python3.11/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~/mambaforge/envs/gphoton2/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File ~/mambaforge/envs/gphoton2/lib/python3.11/site-packages/quickbin/base.py:81, in bin2d.<locals>.make_interrupter.<locals>.interrupter(signalnum, frame)
#      79 def interrupter(signalnum, frame):
#      80     INTERRUPTS_RECEIVED.append(signal.SIGINT)
# ---> 81     raise KeyboardInterrupt
#
# KeyboardInterrupt:
